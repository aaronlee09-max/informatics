# %% [markdown]
# # 정답 노트북

# %%
name = input('이름: ')
print(name)

# %%
a = input('수: ')
print(a * 2)

# %%
a = int(input('수: '))
print(a * 2)

# %%
print(10)
a = 20
print(a)
print(3 + 5)
print('합', 3, 5)

# %%
adult = 50000
child = 30000
n = int(input('대인: '))
m = int(input('소인: '))
print(adult * n + child * m)
