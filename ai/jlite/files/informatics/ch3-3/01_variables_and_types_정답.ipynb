# %% [markdown]
# # 정답 노트북
#
# 선생님 실습 노트북과 같은 구성입니다. 빈칸만 채운 버전이에요. 먼저 빈칸 노트북으로 풀어 본 뒤 비교하세요.

# %% [markdown]
# # 1. 변수와 자료형
#
# > 고등학교 정보(천재교육) Ⅲ. 알고리즘과 프로그래밍 · 03 프로그래밍의 이해 (p.110~115)
#
# **이름:** __________ &nbsp;&nbsp; **학번:** __________

# %% [markdown]
# ## 1️⃣ 변수
#
# **변수**는 프로그래밍에서 값을 저장하는 **기억 공간**이다. 등호(`=`)를 이용하여 변수에 값을 저장하고, 저장된 값을 변경할 수 있다.
#
# > **형식** `변수명 = 변수에 저장할 값(상수, 변수, 수식 등)`
#
# **변수명 지정 규칙**
#
# - 알파벳 대소문자, 한글, 언더 바(`_`), 숫자만을 사용할 수 있다.
# - `if`, `for` 등과 같은 파이썬 예약어는 변수명으로 사용할 수 없다.
# - 알파벳 대소문자는 구별해서 사용한다.
# - 첫 글자에 숫자가 올 수 없다.

# %%
# 예제 5. 변수에 값을 저장하고 값을 변경해 보자.
# a에 정수 10을 저장하기
a = 10
# b, c에 실수 2.5와 문자 'A'를 순서대로 저장하기
b , c = 2.5, 'A'
print(a, b, c)
# a에 저장된 값에 2를 곱하기
a = a * 2
print(a, b, c)

# %% [markdown]
# ### 🙌 활동 12
#
# 다음은 이름, 나이, 연락처 정보를 저장하는 화면과 프로그램이다. **빈칸에 들어갈 값을 채워 보자.**

# %%
# 활동 12
name = "김민지"
age = 17
phone = "010-1234-5678"
print(name, age, phone)

# %% [markdown]
# ## 2️⃣ 자료형
#
# **자료형**은 변수에 저장될 데이터가 어떤 유형인지 구분하는 것이다.

# %%
a = 3
print(type(a))
b = 3.14
print(type(b))
c = 'Hello'
print(type(c))
d = True
print(type(d))

# %%
# 활동 13 체질량 지수
h = 1.7
w = 60
bmi = w / (h ** 2)
print(bmi)
print(18.5 <= bmi < 23)

# %%
# 활동 14 혈압
a, b = 135, 88
print("수축기 혈압", a, "이완기 혈압", b)
print("정상 혈압:", a < 120 and b < 80)
print("주의 혈압:", 120 <= a <= 129 and b < 80)
print("고혈압 전 단계:", 130 <= a <= 139 or 80 <= b <= 89)
print("고혈압:", a >= 140 or b >= 90)
